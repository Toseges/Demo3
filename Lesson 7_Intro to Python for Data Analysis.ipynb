# %%
## INTRO  TO  Data Analysis #

# %%
#The first thing to do is to import pandas

import pandas as pd # You use pandas for the same thing you use excel for

#Next is to numpy as np, pandas does more of the complicated task. #Numpy represents data as arrays, but pandad rep
#resents data as in the form of spread sheet

import numpy as np

# Libraries for data visulaization

import matplotlib.pyplot as plt

import seaborn as sns

import plotly.express as px

# %%
# From dictionary
# Creating a data frame from the scratch
name_dict  = {
     'name': ['ade', 'sola', 'tola', 'john'],
     'age' : [23,26,13,25],
     'salary': [200,450,560,300]
}

# %%
data = pd.DataFrame(name_dict)

data
# Out:
#    name  age  salary
# 0   ade   23     200
# 1  sola   26     450
# 2  tola   13     560
# 3  john   25     300

# %%
# from lists of lists- we move row by row, in dict we move column by column

data_list = [['ade',22,420],
             ['john',22,420],
             ['tade', 32,4200],
             ['adewale',26, 320],
             ['Rachel', 42,420]]

data_2 = pd.DataFrame(data=data_list,columns= ['name','age','salary'])

data_2
# Out:
#       name  age  salary
# 0      ade   22     420
# 1     john   22     420
# 2     tade   32    4200
# 3  adewale   26     320
# 4   Rachel   42     420

# %%
# load from a local file- This is what will be done most time

websites_df = pd.read_csv('abc.csv')

# or using the path
websites_df = pd.read_csv(r'/Users/tosinogeds/Desktop/Python_Dataclass/abc.csv')

# %%
websites_df
# Out:
#           Website                                          Image URL  \
# 0             AOL  https://cdn.iconscout.com/icon/free/png-256/ao...
# 1         Prodigy  https://cdn.worldvectorlogo.com/logos/prodigy.svg
# 2       Bloomberg  https://i.pinimg.com/originals/71/b5/70/71b570...
# 3           Apple  https://upload.wikimedia.org/wikipedia/commons...
# 4             MTV  https://upload.wikimedia.org/wikipedia/commons...
# 5            IMBD  https://upload.wikimedia.org/wikipedia/commons...
# 6             BBC  https://www.newbridge-health.org.uk/wp-content...
# 7      Britannica  https://www.britannica.com/resources/images/EB...
# 8           Yahoo  https://cdn.iconscout.com/icon/free/png-256/ya...
# 9             MSN  https://www.logolynx.com/images/logolynx/f8/f8...
# 10         Excite  https://res-5.cloudinary.com/crunchbase-produc...
# 11      Geocities  https://i.kym-cdn.com/photos/images/newsfeed/0...
# 12          Lycos  https://user-images.strikinglycdn.com/res/hrsc...
# ...

# %% [markdown]
# ### Connecting to Mysql database

# %%
import mysql.connector
from mysql.connector import Error # This has an error because we do not have a mysql.connector, so we load it first
#once only when in use for the first time , with the code (pip install mysql-connector-python)
# We don not have to do it again except we have formatted the entire laptop
# Out:
#   Cell In[15], line 4
#     pip install mysql-connector-python
#         ^
# SyntaxError: invalid syntax

# %%
import mysql.connector
from mysql.connector import Error

# %%
# set up an instance of mysql server

def connect_server(host_name, user_name, password):
    connection = None #This is incase our data runs into any problem
    try:
        connection = mysql.connector.connect(
            host
        
        
        
        )
